# %% [markdown]
# ## LASK2057 Introduction to Analytics in Accounting
# ## Lecture 1: Python crashcourse
# Crashcourse basis and more examples: https://www.w3schools.com/python/default.asp

# %% [markdown]
# # Printing with python

# %%
print("Hello, World!")

# %%
#Use \n for new line
print("Hello, \nWorld!")

# %%
print(3)

# %%
print(1+2)

# %%
print(10/2)

# %% [markdown]
# # Adding comments

# %%
#This is a comment
print("I made a comment")

# %%
#comments are not interpret as code
#print("Hello")
print("Bye")

# %% [markdown]
# # Exercise
# * Print your name
# * make a comment

# %% [markdown]
# # Variables
# A variable is created the moment you first assign a value to it.
# Note that variables are case sensitive.

# %%
x = 1
y = 2
z = "hello"

# %%
print(x)

# %%
print(X)

# %%
q = x+y
print(q)

# %% [markdown]
# Printing a string with a variable

# %%
x = "Hello"
print(f" {x} world!")

# %% [markdown]
# Different datatypes

# %%
print(z)

# %%
print(x+z)

# %%
print(x,z)

# %%
a = float(10)
print(a)

# %%
b = int(10)
print(b)

# %%
c = str(10)
c

# %% [markdown]
# Print the data type of a variable

# %%
print(type(c))

# %% [markdown]
# Boolean values

# %%
a = 1 < 2
print(a)

# %%
b = 2 < 1
print(b)

# %% [markdown]
# ## Python operators needed on this course

# %%
#Adding
1+1

# %%
#Substracting
3-1

# %%
#Multiply
2*2

# %%
#Division
4/2

# %%
#Modulo
9%3

# %%
10%3

# %%
#Assingment operators
x = 5
x +=3
x

# %%
x -= 5
x

# %% [markdown]
# Comparison operators
# * Equal ==
# * Not equal !=
# * Greater than >
# * Less than <
# * Greater than or equal to >=
# * Less than or equal to <=

# %%
#Example
1 != 2

# %%
1 >= 2

# %% [markdown]
# Logical operators
# * and
# * or
# * not

# %%
print(1<2 and 3>2)

# %%
print(1<2 or 2>3)

# %%
print(not(1<2 and 3>2))

# %% [markdown]
# # Exercise
# * Test different operators using both numbers and variables

# %% [markdown]
# # Lists

# %%
mylist = ["first", "second", "third"]
print(mylist)

# %%
mylist = ["first", "first", "second", "third"]
print(mylist)

# %%
#list length
print(len(mylist))

# %%
mylist = list(("first", "second", "third"))
print(mylist)

# %% [markdown]
# List indexing

# %%
print(mylist[1])

# %%
#note!
print(mylist[0])

# %%
#last item
print(mylist[-1])

# %%
#range
print(mylist[:2])

# %%
print(mylist[1:3])

# %% [markdown]
# Note: The search will start at index 1 (included) and end at index 3 (not included).

# %% [markdown]
# # Exercise
#
# * Make a list and try indexing

# %% [markdown]
# ## Creating loops and indentation
#
# Indentation in Python is either one tab or four spaces. It is recommended to use only one or the other.

# %%
for x in mylist:
  print(x)

# %%
#Note!
for x in mylist:
print(x)

# %%
for i in range(len(mylist)):
  print(mylist[i])

# %%
i = 0
while i < len(mylist):
  print(mylist[i])
  i += 1

# %% [markdown]
# ## Joining lists

# %%
list1 = ["a", "b", "c"]
list2 = [1, 2, 3]

# %%
list3 = list1 + list2
print(list3)

# %%
#append

list1.append("d")
print(list1)

# %%
for x in list2:
  list1.append(x)

print(list1)

# %% [markdown]
# ## Exercise
#
# * Join two lists
# * Create a new for loop

# %% [markdown]
# ## Tuples and Sets
# Similar to lists.
# Learn more [here](https://www.w3schools.com/python/python_tuples.asp) and [here](https://www.w3schools.com/python/python_sets.asp).

# %% [markdown]
# ## If else and for loops

# %%
a = 5
b = 10

# %%
if a > 0 :
  print("The number is positive")

# %%
if a < b:
  print("a is smaller than b")

# %%
#Note the indentation
if a > b:
  print("a is greater than b")
else:
  print("a is not greater than b")

# %%
if a > b:
  print("a is greater than b")
elif a < b:
  print("a is smaller than b")
else:
  print("a is equal to b")

# %%
c = 9

if c % 2 == 0:
  print("c is even")
else:
  print("c is not even")

# %%
#for loop

# %%
#while loop

# %% [markdown]
# ## Basic functions

# %%
def test_function():
  print("I made a function")

test_function()

# %%
def feet_to_m(feet):
  return feet*0.3048

print(feet_to_m(70))

# %%
def feet_to_m(feet):
  return print(f" {feet} feet is {feet*0.3048} meters")

feet_to_m(70)

# %% [markdown]
# ## Exercise
#
# * Create a function that will calculate the area of a square when given the side

# %% [markdown]
# ## Dates and time

# %%
#this is how we can import modules outside of built-in functions
import datetime

# %%
x = datetime.datetime.now()
print(x.year)

# %%
print(x.day)

# %%
x = datetime.datetime(2026, 10, 31)
print(x)

# %% [markdown]
# ## Math

# %%
x = [1, 2, 3]

min(x)

# %%
max(x)

# %%
import math

# %%
x = math.sqrt(16)
x

# %%
x = math.pi
x

# %% [markdown]
# ## Input

# %%
name = input("What's your name?")
print(f"Hello {name}")

# %%
print("Check is your number even")
x = input("Enter your numer:")

if int(x) % 2 == 0:
  print("Your number is even")
else:
  print("Your number is not even")

# %% [markdown]
# ## Exercise
#
# * Modify your square function to take the side of the square through input
